# %%
www.anaconda.com
www.github.com

laptop/desktop----> 4GB of RAM

# %%
a. www.anaconda.com----> python distribution version
Steps to be folowed.
1. open the link
2. select get started option----seen at the top right side of the website.
3. select the anconda individual edition------>click on-->downlaod
4. select python 3.8 version and click downlaod(according to your OS choose the downalod option)
5. once it gets downloaded, run it in your system--->click--->next--->next----->next---->next-and then install
6. shortcut icon willbe created on the desktop as --->Anacond navigator----->from that launch jupyter notebook
7. Open CMD or terminal and type.......> jupyter notebook and press enter(alternative approach of opening)
8. it will be opened in the internet explorer or google chrome.
9. select new--->open python notebook---->thats all

# %%
b. www.github.com -----> online code storage repository:
    
steps to be folowed :

1.open the link
2.complete the sign up process.
3.do sign in the github
4.topleft side--->create new repository
5.create the repository name--->python_fundamentals.
6.add description---> all my pratise files wil be saved here.
7.upload files---> and do commit the file.

final step :
    
8.copy the github URL from the browser and send to codetraining01@gmail.com for review.
