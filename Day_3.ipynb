# %%
x = 5
y = 3

print(x)
print(y)
# Out:
# 5
# 3

# %%
z = x+y
print(z)
# Out:
# 8

# %%
Rules for declaring the variables in python.

# %%
Rule no. 1 : No name spaces while declaring the varible name in python.

# %%
first name = 'Shafia'

print(first name)
# Out:
#   File "<ipython-input-2-71ef07c89271>", line 1
#     first name = 'Shafia'
#           ^
# SyntaxError: invalid syntax

# %%
firstname = 'Shafia'
print(firstname)
# Out:
# Shafia

# %%
Rule no. 2 : A variablename should not strat with a number **

# %%
1name = 'rahul'
print(1name)
# Out:
#   File "<ipython-input-4-f35bfbfe9e76>", line 1
#     1name = 'rahul'
#      ^
# SyntaxError: invalid syntax

# %%
name1 = 'rahul'
print(name1)
# Out:
# rahul

# %%
Rule no. 3 : A variable name should not contain nay special characters.

# %%
@$%& =======> are not allowed to be used in the varible name.

# %%
name@ = 'john'

print(name@)
# Out:
#   File "<ipython-input-6-d749ecc3f7a4>", line 1
#     name@ = 'john'
#           ^
# SyntaxError: invalid syntax

# %%
introduction to data types in python:
    
    1. String
    2. list
    3.tuple
    4.dictionaries
    5.number ----> integers and floats(decimals)

# %%
Classification of data types in python :
    
    1. mutable datatypes ---> which we can edit or alter (flexible data type)
    
    2. immutable data types -----> which we cannot edit or alter (fixed data type)

# %%
intriduction to string datatype :

# %%
overview : A string is a series of characters enclosed in quotes.
    
classification : it is classified as an imutable data type
    
declaration and short form : string-----> str
    
3 possible approaches for declaring a string :
    
    1. single quotes
    2. double quotes
    3. tripple quotes

# %%
name = 'sirish'   #single quote

print(name)
# Out:
# sirish

# %%
name2 = naveed"   #double quote

print(name2)
# Out:
# naveed

# %%
name3 = """keerthi"""  #tripple quote

print(name3)
# Out:
# keerthi

# %%
introduction to string methods :

# %%
# methods are built in programs that are available to use.

# %%
type ----> it is usedto confirm the data types

# %%
type(name)
# Out:
# str

# %%
type(name2)
# Out:
# str

# %%
type(name3)
# Out:
# str
